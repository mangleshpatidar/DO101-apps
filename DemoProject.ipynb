# %% [markdown]
# <a href="https://colab.research.google.com/github/mangleshpatidar/DO101-apps/blob/master/DemoProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# 5           5   7.1   48.0          1
# 6           6   5.7  143.0          0
# 7           7   5.0   63.0          0
# 8           8   6.1  156.0          0
# 9           9   5.1   66.0          0

# %% [markdown]
# Data Set

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 44   7.5   61.0
# 86   5.1  128.0
# 98   6.3  103.0
# 82   6.5   37.0
# 32   7.0  139.0
# ..   ...    ...
# 69   8.5  120.0
# 87   5.7  132.0
# 23   4.7   87.0
# 79   6.5   90.0
# 20   6.6  120.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 1    5.9  106.0
# 7    5.0   63.0
# 72   7.3  116.0
# 39   4.6  146.0
# 45   6.0   66.0
# 83   7.5  130.0
# 59   4.8  112.0
# 15   5.1  176.0
# 19   5.2  132.0
# 24   4.7  121.0

# %%
Y_train
# Out:
# 44    1
# 86    0
# 98    1
# 82    1
# 32    1
#      ..
# 69    1
# 87    1
# 23    0
# 79    1
# 20    1
# Name: placement, Length: 90, dtype: int64

# %%
Y_test
# Out:
# 1     0
# 7     0
# 72    1
# 39    0
# 45    1
# 83    1
# 59    0
# 15    0
# 19    0
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.28143262, -1.56681649],
#        [-0.81545712,  0.09071043],
#        [ 0.23298775, -0.52776976],
#        [ 0.40772856, -2.16055747],
#        [ 0.84458059,  0.36284171],
#        [-0.20386428,  1.03080032],
#        [-0.29123469,  0.38758092],
#        [-1.42704996, -2.03686143],
#        [-1.07756834,  1.10501794],
#        [ 1.98039586,  1.08027874],
#        [ 0.66983978, -0.03298561],
#        [ 0.84458059,  1.84719418],
#        [ 0.14561734, -0.28037769],
#        [ 0.66983978, -0.3051169 ],
#        [-0.5533459 ,  0.26388488],
#        [-1.42704996,  0.61023379],
#        [-1.16493874, -1.78946936],
#        [-0.29123469,  1.10501794],
#        [ 1.10669181, -1.83894777],
#        [-0.81545712, -1.44312045],
#        [ 0.93195099,  0.65971221],
#        [-0.99019793, -1.56681649],
#        [-1.77653158, -0.60198739],
#        [ 1.28143262,  0.83288666],
#        [ 1.19406221,  0.18966726],
#        [-1.77653158, -1.22046758],
#        [-0.72808671, -0.84937946],
# ...

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.11649387, -0.45355214],
#        [-0.90282753, -1.51733807],
#        [ 1.10669181, -0.20616006],
#        [-1.25230915,  0.53601617],
#        [-0.02912347, -1.44312045],
#        [ 1.28143262,  0.14018884],
#        [-1.07756834, -0.3051169 ],
#        [-0.81545712,  1.2781924 ],
#        [-0.72808671,  0.18966726],
#        [-1.16493874, -0.08246403]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,Y_train)

# %%
Y_pred=clf.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 0, 1, 0, 1, 1, 0, 0, 0, 0])

# %%
Y_test
# Out:
# 1     0
# 7     0
# 72    1
# 39    0
# 45    1
# 83    1
# 59    0
# 15    0
# 19    0
# 24    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# Plotting decision regions
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
